# %%
import chemview
chemview.enable_notebook()

# %%
from chemview import MolecularViewer
import numpy as np

# %%
MolecularViewer(coordinates = np.array([[0.0, 1.1, 0.1], [1, 0, 0]], 'float32'),
                topology = {'atom_types': ["Ar", 'Ne'],
                            'bonds': []})
