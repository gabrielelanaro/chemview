# %%
import numpy as np
import chemview

from chemview import RepresentationViewer
from chemview.trajectory import TrajectoryViewer
from IPython.display import display
chemview.enable_notebook()

# %%
import mdtraj as md
traj = md.load_pdb('2M6K.pdb')
print traj
# Out:
# <mdtraj.Trajectory with 30 frames, 4462 atoms, 292 residues, and unitcells>

# %%
tv = TrajectoryViewer(traj)
tv
# Out:
# <img src="data:image/png;base64,..."/>

# %%
rv = RepresentationViewer()

# Atoms as points
coordinates = traj.xyz[0].astype('float32')
rv.add_representation('points', {'coordinates': coordinates})

# Bonds as lines
bonds_start = [b[0].index for b in traj.topology.bonds]
bonds_end = [b[1].index for b in traj.topology.bonds]
colors = [0xffffff] * len(coordinates)
rv.add_representation('lines', {'startCoords': coordinates[bonds_start],
                                'endCoords': coordinates[bonds_end],
                                'startColots': colors,
                                'endColors': colors})

rv

# %%
from IPython.display import HTML

HTML('''
<script type='text/javascript'></script>
''')

# %%
rv.widgets
# Out:
# {u'237d94478a244b2999c745f508215840': <chemview.widget.RepresentationViewer at 0x7fb7b4532a50>,
#  u'2e17ce72436544bfbdd403152eff1a79': <chemview.widget.RepresentationViewer at 0x7fb7b9fec3d0>,
#  u'2fed9d292d8845dda78a09c49ba66d90': <chemview.widget.RepresentationViewer at 0x7fb7a8eb2490>,
#  u'33f5c7bb209346c68ea868c322d46ee9': <chemview.widget.RepresentationViewer at 0x7fb7b453ec90>,
#  u'444f43ca24784621aa7700e99a40524f': <chemview.widget.RepresentationViewer at 0x7fb7b4532350>,
#  u'4a9a87c5271c465d959173f1f91453bb': <chemview.widget.RepresentationViewer at 0x7fb7a895f690>,
#  u'534ec991cff147ef90916091e3bc36f7': <chemview.widget.RepresentationViewer at 0x7fb7b4532110>,
#  u'5c26c0f0bd4748869ce907c2a97fb04e': <chemview.widget.RepresentationViewer at 0x7fb7a895f390>,
#  u'681146c53b4e46a9aee7ff056e9541ad': <chemview.widget.RepresentationViewer at 0x7fb7a895f150>,
#  u'6d5e953f510349fea1c2fa1fa08b30a6': <chemview.widget.RepresentationViewer at 0x7fb7a895fa10>,
#  u'75be586e6e4340598e48b64d20367f33': <chemview.widget.RepresentationViewer at 0x7fb7b454f750>,
#  u'7d07971844f1451fb830dfa829c9fc91': <chemview.widget.RepresentationViewer at 0x7fb7b4532e90>,
#  u'9256db07d43942b4aee7c4c360024f78': <chemview.widget.RepresentationViewer at 0x7fb7ba0049d0>,
#  u'970de67fe0c74b788075002197fa0421': <chemview.widget.RepresentationViewer at 0x7fb7b45327d0>,
#  u'995cdee783594fbf98ad118d21f664c0': <chemview.widget.RepresentationViewer at 0x7fb7b4526390>,
#  u'adeebd7ef6764ce1849d0a389b449101': <chemview.widget.RepresentationViewer at 0x7fb7b453e650>,
#  u'b5f9837618cc43968f8de0b021059fd7': <chemview.widget.RepresentationViewer at 0x7fb7b454f510>,
#  u'c77b13dc43714e1ca32b80590df54d67': <chemview.widget.RepresentationViewer at 0x7fb7a895f990>,
#  u'c9227a7dddd04e78bdffdc634ae9d196': <chemview.widget.RepresentationViewer at 0x7fb7b453e7d0>,
#  u'cb5ee3d1f3aa467aae736f497ad4921a': <chemview.widget.RepresentationViewer at 0x7fb7b4532a10>,
#  u'cff2e22b57a44aa5a6dbee22d49772f2': <chemview.widget.RepresentationViewer at 0x7fb7a8eb2610>,
#  u'd79e332a40bd4d66b49924eae867bbd1': <chemview.widget.RepresentationViewer at 0x7fb7b453e110>,
#  u'd87b29e999d54f0d9d16306352e10574': <chemview.widget.RepresentationViewer at 0x7fb7b4532590>,
#  u'e15c7475d1df41989e1fc832e25e334f': <chemview.widget.RepresentationViewer at 0x7fb7b453e810>,
#  u'e3c69a03f65c42dfa788b68f26c68907': <chemview.widget.RepresentationViewer at 0x7fb7b4526710>,
#  u'eec12c7fbd5c4fd6ac4e5fb4b4336ec9': <chemview.widget.RepresentationViewer at 0x7fb7a895f110>,
#  u'f7de229fe7044c8cb2d3ad6ddd3ba889': <chemview.widget.RepresentationViewer at 0x7fb7b453ea50>}
