# %%
from chemview  import enable_notebook, MolecularViewer
from chemview.trajectory import TrajectoryViewer
from chemview.export import display_static
enable_notebook()

# %%
# We use MDTraj to get a secondary structure
import mdtraj as md
traj = md.load_pdb('2M6K.pdb')
print traj
# Out:
# <mdtraj.Trajectory with 30 frames, 4462 atoms, 292 residues, and unitcells>

# %%
top = {}
top['atom_types'] = [a.element.symbol for a in traj.topology.atoms]
top['atom_names'] = [a.name for a in traj.topology.atoms]
top['bonds'] = [(a.index, b.index) for a, b in traj.topology.bonds]
top['secondary_structure'] = md.compute_dssp(traj[0])[0]
top['residue_types'] = [r.name for r in traj.topology.residues ]
top['residue_indices'] = [ [a.index for a in r.atoms] for r in traj.topology.residues ]

mv = MolecularViewer(traj.xyz[0], top)
mv.cylinder_and_strand()
mv
# Out:
# /home/gabriele/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.py:364: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)
#             <canvas id="molecular_viewer"></canvas>
#             <script>
#
#             require(['chemview'], function () {
#                 console.log('done loading');
#                 var canvas = $("#molecular_viewer").css({width: 400, height: 400});
#                 var mv = new MolecularViewer(canvas);
#                 var data = {"representations": [{"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "cRtNP3EbjT+fzWq/6pVCP6JFnj8CvHW/0ZFsP9nOpz+jAUy/TKaCP6yLsz87AT2/h6eXPx04xz9YOVS/KxilP4bJzD/ImGu/3SS+Px3JvT+lToC/zTvOP5p3tD9okX2/nKK7PyEfnD8m5HO/ZDu3Pxzrij+C4me/2IGrPx6niD+QoJC/"}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": ""}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "2PA0v/FjJMBbQl4/ETZMv9XnKsDOGVE/Fmpdv7snK8BrK4Y/TtFxv2reLcBqvJQ/0ZGMv9NNIsAN4I0/qDWdvzojHsARNow/KH60v+AtKMBg5ZA/"}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "RwPAv+jZNMACKwc/gEjHv2EyOcDhC9M+JlO1v9xGL8DhepQ+ksuvv/p+KsAhsDI+yAetv94CMcASpT29"}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "..."}}}, {"type": "smoothtube", "options": {"color": 16777215, "radius": 0.05, "resolution": 4, "coordinates": {"type": "float32", "data": "NV5KP4xKGsCeXim/woZHP1mGIMDUK0W/"}}}, {"type": "cylinders", "options": {"colors": {"type": "uint32", "data": "..."}, "endCoords": {"type": "float32", "data": "aW+oP86I0j5cIKG+WvWxP4hjnT+cxNg/W0IuPyzUsj/tDd4/X5jMPUOt+T+qgpE/cRtNP3EbjT+fzWq/bedbP1CNx78Ab+G/E2GDPsGorL9wzqC/nYAGwGuaZ78Q6Qc/2PA0v/FjJMBbQl4/RwPAv+jZNMACKwc//kNavxPyRcAgQTG+NV5KP4xKGsCeXim/"}, "radii": {"type": "float32", "data": "..."}, "startCoords": {"type": "float32", "data": "D5xzPg5PL7yWIe4+xSAAQKRwLT/XozA/bHh6vtcSmj/r4vY/4liPv+C+nj/99oU/EFiZPmlv8L2/fR2/2IGrPx6niD+QoJC/FvurvkJgxb50tdW+g8AOwACRhr9fmEy+A3iLPvJBF8DBqAQ/KH60v+AtKMBg5ZA/yAetv94CMcASpT29Q605P18Hrr6GOFa+"}}}]};
#
#                 mv.deserialize(data);
#                 mv.animate();
#
#                 // Give it a nice zoom
#                 mv.controls.dollyIn(1.9);
#
#                 mv.resize(canvas.width(), canvas.height());
#             });
#
#             </script>

# %%
# Display static
display_static(mv)

# %%
import json

def callback(content):
    with open('data.json', 'wb') as fp:
        json.dump(content['json'], fp)

mv._connect_event('serialize', callback)
mv._remote_call('_handle_serialize')

# %%
# %%javascript
#
# var prefix = "https://rawgit.com/gabrielelanaro/chemview/master/chemview/static/";
#
# require.config({
#     paths: {
#         'jquery': prefix + 'jquery.min',
#         'jqueryui': prefix + 'jquery-ui.min',
#         'exporter': prefix + 'objexporter.js',
#         'three': prefix + 'three.min',
#         'base64-arraybuffer': prefix + 'base64-arraybuffer',
#         'ArcballControls' : prefix + 'ArcballControls',
#         'chemview': prefix + 'chemview',
#     },
#     shim: {
#         three: {
#             exports: 'THREE'
#         },
#
#         chemview: {
#             deps: ['three', 'ArcballControls', 'base64-arraybuffer'],
#             exports: 'MolecularViewer'
#         },
#
#         ArcballControls: {
#             deps: ['three'],
#             exports: 'THREE.ArcballControls',
#         },
#     },
# });

# %% [markdown]
# Serialize this thing

# %%
# %%html
#
# <canvas id="molecular_viewer"></canvas>
# <script>
#
# require(['chemview'], function () {
#     console.log('done loading');
#     var canvas = $("#molecular_viewer").css({width: 400, height: 400});
#     var mv = new MolecularViewer(canvas);
#     var prefix = "https://rawgit.com/gabrielelanaro/chemview/master/";
#
#     var datafile = prefix + 'docs/source/_static/protein_rendered.json';
#
#     $.getJSON(datafile, function (data){
#         mv.deserialize(data);
#         mv.animate();
#
#     // Give it a nice zoom
#         mv.controls.dollyIn(1.9);
#     });
#
#     mv.resize(canvas.width(), canvas.height());
# });
#
# </script>
